# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
data = [
    [1,2],
    [3,3],
    [2,2],
    [8,8],
    [6,6],
    [7,7],
    [-3,-3],
    [-2,-4],
    [-7,-7],
]

df = pd.DataFrame(data = data, columns = ['x','y'])
df
# Out:
#    x  y
# 0  1  2
# 1  3  3
# 2  2  2
# 3  8  8
# 4  6  6
# 5  7  7
# 6 -3 -3
# 7 -2 -4
# 8 -7 -7

# %%
X = df[['x','y']].to_numpy()
X
# Out:
# array([[ 1,  2],
#        [ 3,  3],
#        [ 2,  2],
#        [ 8,  8],
#        [ 6,  6],
#        [ 7,  7],
#        [-3, -3],
#        [-2, -4],
#        [-7, -7]])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-0.14142136,  0.09025874],
#        [ 0.28284271,  0.29334089],
#        [ 0.07071068,  0.09025874],
#        [ 1.34350288,  1.30875168],
#        [ 0.91923882,  0.90258736],
#        [ 1.13137085,  1.10566952],
#        [-0.98994949, -0.92515205],
#        [-0.77781746, -1.12823421],
#        [-1.83847763, -1.73748068]])

# %%
k = 2
kmeans = KMeans(n_clusters=k, n_init=10, random_state=10)
df["cluster"] = kmeans.fit_predict(X_scaled)
df
# Out:
#    x  y  cluster
# 0  1  2        1
# 1  3  3        1
# 2  2  2        1
# 3  8  8        1
# 4  6  6        1
# 5  7  7        1
# 6 -3 -3        0
# 7 -2 -4        0
# 8 -7 -7        0

# %%
centers_scaled = kmeans.cluster_centers_
centers = scaler.inverse_transform(centers_scaled)
centers
# Out:
# array([[-4.        , -4.66666667],
#        [ 4.5       ,  4.66666667]])

# %%
plt.figure()
plt.scatter(df["x"], df["y"], c=df["cluster"], s=80)
plt.scatter(centers[:, 0], centers[:, 1], marker="X", s=250)
plt.axhline(0)
plt.axvline(0)
plt.title(f"K-means clustering (k={k})")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
k = 3
kmeans = KMeans(n_clusters=k, n_init=10, random_state=10)
df["cluster"] = kmeans.fit_predict(X_scaled)
centers_scaled = kmeans.cluster_centers_
centers = scaler.inverse_transform(centers_scaled)
plt.figure()
plt.scatter(df["x"], df["y"], c=df["cluster"], s=80)
plt.scatter(centers[:, 0], centers[:, 1], marker="X", s=250)
plt.axhline(0)
plt.axvline(0)
plt.title(f"K-means clustering (k={k})")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
k = 4
kmeans = KMeans(n_clusters=k, n_init=10, random_state=10)
df["cluster"] = kmeans.fit_predict(X_scaled)
centers_scaled = kmeans.cluster_centers_
centers = scaler.inverse_transform(centers_scaled)
plt.figure()
plt.scatter(df["x"], df["y"], c=df["cluster"], s=80)
plt.scatter(centers[:, 0], centers[:, 1], marker="X", s=250)
plt.axhline(0)
plt.axvline(0)
plt.title(f"K-means clustering (k={k})")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
